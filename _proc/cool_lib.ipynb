# %% [raw]
# ---
# description: This library provides cool features for data processing and analysis.
# output-file: cool_lib.html
# title: cool library
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/mettafore/learn-nbdev/blob/main/learn_nbdev/cool_lib.py#L9){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(go_duckies_yourself)
# Out:
# ---
#
# [source](https://github.com/mettafore/learn-nbdev/blob/main/learn_nbdev/cool_lib.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### go_duckies_yourself
#
# >      go_duckies_yourself (to)
#
# *Tells someone to go duckies themselves.*

# %%
go_duckies_yourself("luvsuneja")
# Out:
# 'go duckies yourself luvsuneja'

# %%
assert go_duckies_yourself("luvsuneja") == "go duckies yourself luvsuneja"

# %%
from fastcore.test import *

# %%
test_eq(go_duckies_yourself("luvsuneja"), "go duckies yourself luvsuneja")

# %%
from IPython.display import display,SVG

# %%
display(SVG('<svg height="100" xmlns="http://www.w3.org/2000/svg"><circle cx="50" cy="50" r="40"/></svg>'))
